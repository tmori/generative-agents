# %% [markdown]
# # Generative agents for applaud
#
# Repository: https://github.com/tmori/generative-agents

# %% [markdown]
# ## Create & Install Environments
# Please set your open api key on OPEN_API_KEY

# %%
# %env OPENAI_API_KEY=

# %%
# %pwd

# %%
# !git clone https://github.com/tmori/generative-agents.git

# %%
# !pip3 install openai
# !pip3 install chromadb
# !pip3 install tiktoken
# !pip3 install pypdf
# !pip3 install langchain
# !pip3 install unstructured
# !pip3 install tabulate
# !pip3 install scikit-learn

# %% [markdown]
# ## Upload PDF Files
#
# Please upload pdf documents on `generative-agents/applaud_data/documents/dbs`.
#
# Example:
#
# ![image.png](data:image/png;base64,...)

# %%
# %cd /content/generative-agents/applaud_data/documents/dbs

# %%
from google.colab import files

uploaded_files = files.upload()

# %% [markdown]
# # Write uploaded file names on document.list
#
# Example:
#
# ```
# chap01
# chap02
# ```

# %% [markdown]
# # Do applaud!

# %%
# %cd /content/generative-agents

# %%
# !bash tools/do_applaud.bash "kanetugu2018"
